# %%
# Install all necessary packages

# !pip install keras-ocr
# !pip install matplotlib
# !pip install opencv-python
# !pip install --force-reinstall -v "tensorflow==2.15.1"
# !pip install tensorflow==2.15
# !pip install groq

# Import all necessary libraries

# !pip install keras_ocr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras-ocr
#   Downloading keras_ocr-0.9.3-py3-none-any.whl.metadata (8.6 kB)
# Collecting editdistance (from keras-ocr)
#   Downloading editdistance-0.8.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.9 kB)
# Collecting efficientnet==1.0.0 (from keras-ocr)
#   Downloading efficientnet-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting essential_generators (from keras-ocr)
#   Downloading essential_generators-1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: fonttools in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras-ocr) (4.56.0)
# Collecting imgaug (from keras-ocr)
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting pyclipper (from keras-ocr)
#   Downloading pyclipper-1.3.0.post6-cp39-cp39-macosx_10_9_universal2.whl.metadata (9.0 kB)
# Collecting shapely (from keras-ocr)
#   Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras-ocr) (4.67.1)
# Collecting validators (from keras-ocr)
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet==1.0.0->keras-ocr)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting scikit-image (from efficientnet==1.0.0->keras-ocr)
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from imgaug->keras-ocr) (1.15.0)
# Requirement already satisfied: numpy>=1.15 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras-ocr) (2.0.2)
# Requirement already satisfied: scipy in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras-ocr) (1.13.1)
# Requirement already satisfied: Pillow in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras-ocr) (11.1.0)
# Requirement already satisfied: matplotlib in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras-ocr) (3.9.4)
# Collecting opencv-python (from imgaug->keras-ocr)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Collecting imageio (from imgaug->keras-ocr)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting h5py (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr)
#   Downloading h5py-3.13.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Requirement already satisfied: networkx>=2.8 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.2.1)
# Collecting tifffile>=2022.8.12 (from scikit-image->efficientnet==1.0.0->keras-ocr)
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image->efficientnet==1.0.0->keras-ocr)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras-ocr) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug->keras-ocr) (3.21.0)
# Downloading keras_ocr-0.9.3-py3-none-any.whl (42 kB)
# Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Downloading editdistance-0.8.1-cp39-cp39-macosx_11_0_arm64.whl (79 kB)
# Downloading essential_generators-1.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 8.2 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp39-cp39-macosx_10_9_universal2.whl (270 kB)
# Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.2 MB/s eta 0:00:00
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 3.7 MB/s eta 0:00:0000:0100:01m
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
# Downloading h5py-3.13.0-cp39-cp39-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyclipper, essential_generators, validators, tifffile, shapely, opencv-python, lazy-loader, imageio, h5py, editdistance, scikit-image, keras-applications, imgaug, efficientnet, keras-ocr
# Successfully installed editdistance-0.8.1 efficientnet-1.0.0 essential_generators-1.0 h5py-3.13.0 imageio-2.37.0 imgaug-0.4.0 keras-applications-1.0.8 keras-ocr-0.9.3 lazy-loader-0.4 opencv-python-4.11.0.86 pyclipper-1.3.0.post6 scikit-image-0.24.0 shapely-2.0.7 tifffile-2024.8.30 validators-0.34.0
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from opencv-python) (2.0.2)
# Using pip 25.0.1 from /Users/beszabo/Library/Python/3.9/lib/python/site-packages/pip (python 3.9)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
universal2.whl.metadata (3.9 kB)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.1)
#   Obtaining dependency information for tensorboard<2.16,>=2.15 from https://files.pythonhosted.org/packages/37/12/f6e9b9dcc310263cbd3948274e286538bd6800fd0c268850788f14a0c6d0/tensorboard-2.15.2-py3-none-any.whl.metadata
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.1)
#   Obtaining dependency information for tensorflow-estimator<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/b6/c8/2f823c8958d5342eafc6dd3e922f0cc4fcf8c2e0460284cc462dae3b60a0/tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.1)
#   Obtaining dependency information for keras<2.16,>=2.15.0 from https://files.pythonhosted.org/packages/fc/a7/0d4490de967a67f68a538cc9cdb259bff971c4b5787f7765dc7c8f118f71/keras-2.15.0-py3-none-any.whl.metadata
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.15.1)
#   Obtaining dependency information for wheel<1.0,>=0.23.0 from https://files.pythonhosted.org/packages/0b/2c/87f3254fd8ffd29e4c02732eee68a83a1d3c346ae39bc6822dcbcb697f2b/wheel-0.45.1-py3-none-any.whl.metadata
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/9d/47/603554949a37bca5b7f894d51896a9c534b9eab808e2520a748e081669d0/google_auth-2.38.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for google-auth-oauthlib<2,>=0.5 from https://files.pythonhosted.org/packages/1a/8e/22a28dfbd218033e4eeaf3a0533b2b54852b6530da0c0fe934f0cc494b29/google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/3f/08/83871f3c50fc983b88547c196d11cf8c3340e37c32d2e9d6152abe2c61f7/Markdown-3.7-py3-none-any.whl.metadata
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for requests<3,>=2.21.0 from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/7a/13/e503968fefabd4c6b2650af21e110aa8466fe21432cd7c43a84577a89438/tensorboard_data_server-0.7.2-py3-none-any.whl.metadata
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for werkzeug>=1.0.1 from https://files.pythonhosted.org/packages/52/24/ab44c871b0f07f491e5d2ad12c9bd7358e527510618cb1b803a88e986db1/werkzeug-3.1.3-py3-none-any.whl.metadata
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/72/76/20fa66124dbe6be5cafeb312ece67de6b61dd91a0247d1ea13db4ebb33c2/cachetools-5.5.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for pyasn1-modules>=0.2.1 from https://files.pythonhosted.org/packages/77/89/bc88a6711935ba795a679ea6ebee07e128050d6382eaa35a0a47c8032bdc/pyasn1_modules-0.4.1-py3-none-any.whl.metadata
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for requests-oauthlib>=0.7.0 from https://files.pythonhosted.org/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for importlib-metadata>=4.4 from https://files.pythonhosted.org/packages/79/9d/0fb148dc4d6fa4a7dd1d8378168d9b4cd8d4560a6fbf6f0121c5fc34eb68/importlib_metadata-8.6.1-py3-none-any.whl.metadata
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/7f/c0/b913f8f02836ed9ab32ea643c6fe4d3325c3d8627cf6e78098671cafff86/charset_normalizer-3.4.1-cp39-cp39-macosx_10_9_universal2.whl.metadata
#   Using cached charset_normalizer-3.4.1-cp39-cp39-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/c8/19/4ec628951a74043532ca2cf5d97b7b14863931476d117c471e8e2b1eb39f/urllib3-2.3.0-py3-none-any.whl.metadata
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/38/fc/bce832fd4fd99766c04d1ee0eead6b0ec6486fb100ae5e74c1d91292b982/certifi-2025.1.31-py3-none-any.whl.metadata
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for MarkupSafe>=2.1.1 from https://files.pythonhosted.org/packages/4b/c2/fbdbfe48848e7112ab05e627e718e854d20192b674952d9042ebd8c9e5de/MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for zipp>=3.20 from https://files.pythonhosted.org/packages/b7/1a/7e4798e9339adc931158c9d69ecc34f5e6791489d469f5e50ec15e35f458/zipp-3.21.0-py3-none-any.whl.metadata
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for pyasn1<0.7.0,>=0.4.6 from https://files.pythonhosted.org/packages/c8/f1/d6a797abb14f6283c0ddff96bbdd46937f64122b8c925cab503dd37f8214/pyasn1-0.6.1-py3-none-any.whl.metadata
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1)
#   Obtaining dependency information for oauthlib>=3.0.0 from https://files.pythonhosted.org/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl.metadata
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.15.1-cp39-cp39-macosx_12_0_arm64.whl (205.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.7/205.7 MB 720.4 kB/s eta 0:00:0000:0100:07
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.70.0-cp39-cp39-macosx_10_14_universal2.whl (11.5 MB)
# Using cached h5py-3.13.0-cp39-cp39-macosx_11_0_arm64.whl (2.9 MB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.2 MB/s eta 0:00:00
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Downloading ml_dtypes-0.3.2-cp39-cp39-macosx_10_9_universal2.whl (389 kB)
# Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-4.25.6-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading wrapt-1.14.1-cp39-cp39-macosx_11_0_arm64.whl (35 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp39-cp39-macosx_10_9_universal2.whl (197 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: libclang, flatbuffers, zipp, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, setuptools, pyasn1, protobuf, packaging, opt-einsum, oauthlib, numpy, MarkupSafe, keras, idna, grpcio, gast, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, ml-dtypes, importlib-metadata, h5py, google-pasta, astunparse, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/zipp/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/zipp-3.21.0.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/zipp/
#       Successfully uninstalled zipp-3.21.0
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/wheel to 755
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/urllib3/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/urllib3-2.3.0.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/urllib3/
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/typing_extensions.cpython-39.pyc
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/typing_extensions-4.12.2.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/typing_extensions.py
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard_data_server/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard_data_server-0.7.2.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard_data_server/
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/google/protobuf/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/google/_upb/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/google/protobuf/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/protobuf-5.29.3.dist-info/
#       Successfully uninstalled protobuf-5.29.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/packaging/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/packaging-24.2.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/packaging/
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/numpy/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/bin/f2py
#       Removing file or directory /Users/beszabo/Library/Python/3.9/bin/numpy-config
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/numpy-2.0.2.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/numpy/
#       Successfully uninstalled numpy-2.0.2
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/f2py to 755
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/markupsafe/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/MarkupSafe-3.0.2.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/markupsafe/
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/idna/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/idna-3.10.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/idna/
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.70.0
#     Uninstalling grpcio-1.70.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/grpc/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/grpc/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/grpcio-1.70.0.dist-info/
#       Successfully uninstalled grpcio-1.70.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/charset_normalizer/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/bin/normalizer
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/charset_normalizer-3.4.1.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/charset_normalizer/
#       Successfully uninstalled charset-normalizer-3.4.1
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/normalizer to 755
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/certifi/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/certifi-2025.1.31.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/certifi/
#       Successfully uninstalled certifi-2025.1.31
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.1.0
#     Uninstalling absl-py-2.1.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/absl/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/absl/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/absl_py-2.1.0.dist-info/
#       Successfully uninstalled absl-py-2.1.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/werkzeug/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/werkzeug-3.1.3.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/werkzeug/
#       Successfully uninstalled Werkzeug-3.1.3
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-decrypt to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-encrypt to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-keygen to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-priv2pub to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-sign to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/pyrsa-verify to 755
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/requests/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/requests-2.32.3.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/requests/
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/importlib_metadata/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/importlib_metadata-8.6.1.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/importlib_metadata/
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.13.0
#     Uninstalling h5py-3.13.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/h5py/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/h5py-3.13.0.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/h5py/
#       Successfully uninstalled h5py-3.13.0
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.7
#     Uninstalling Markdown-3.7:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/markdown/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/bin/markdown_py
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/Markdown-3.7.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/markdown/
#       Successfully uninstalled Markdown-3.7
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/markdown_py to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/google-oauthlib-tool to 755
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Removing file or directory /Users/beszabo/Library/Caches/com.apple.python/Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/bin/tensorboard
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard-2.18.0.dist-info/
#       Removing file or directory /Users/beszabo/Library/Python/3.9/lib/python/site-packages/tensorboard/
#       Successfully uninstalled tensorboard-2.18.0
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/tensorboard to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/estimator_ckpt_converter to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/import_pb_to_tensorboard to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/saved_model_cli to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/tensorboard to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/tf_upgrade_v2 to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/tflite_convert to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/toco to 755
#   changing mode of /Users/beszabo/Library/Python/3.9/bin/toco_from_protos to 755
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 flatbuffers-25.2.10 gast-0.6.0 google-auth-2.38.0 google-auth-oauthlib-1.2.1 google-pasta-0.2.0 grpcio-1.70.0 h5py-3.13.0 idna-3.10 importlib-metadata-8.6.1 keras-2.15.0 libclang-18.1.1 markdown-3.7 ml-dtypes-0.3.2 numpy-1.26.4 oauthlib-3.2.2 opt-einsum-3.4.0 packaging-24.2 protobuf-4.25.6 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-2.32.3 requests-oauthlib-2.0.0 rsa-4.9 setuptools-75.8.0 six-1.17.0 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.1 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.5.0 typing-extensions-4.12.2 urllib3-2.3.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.14.1 zipp-3.21.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow==2.15
#   Downloading tensorflow-2.15.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.6 kB)
# Collecting tensorflow-macos==2.15.0 (from tensorflow==2.15)
#   Downloading tensorflow_macos-2.15.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-macos==2.15.0->tensorflow==2.15)
#   Downloading ml_dtypes-0.2.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (3.4.0)
# Requirement already satisfied: packaging in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (4.25.6)
# Requirement already satisfied: setuptools in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (1.70.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow==2.15) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (8.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.21.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15) (3.2.2)
# Downloading tensorflow-2.15.0-cp39-cp39-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow_macos-2.15.0-cp39-cp39-macosx_12_0_arm64.whl (208.8 MB)
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 86.0/208.8 MB 902.6 kB/s eta 0:02:17^C
# Defaulting to user installation because normal site-packages is not writeable
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Collecting anyio<5,>=3.5.0 (from groq)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from groq)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from groq)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3,>=1.9.0 (from groq)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting sniffio (from groq)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from groq) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->groq)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3,>=1.9.0->groq)
#   Downloading pydantic_core-2.27.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp39-cp39-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.5 MB/s eta 0:00:00a 0:00:01
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, groq
# Successfully installed annotated-types-0.7.0 anyio-4.8.0 distro-1.9.0 groq-0.18.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 pydantic-2.10.6 pydantic-core-2.27.2 sniffio-1.3.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_ocr in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (0.9.3)
# Requirement already satisfied: editdistance in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (0.8.1)
# Requirement already satisfied: efficientnet==1.0.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (1.0)
# Requirement already satisfied: fonttools in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (4.56.0)
# Requirement already satisfied: imgaug in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (0.4.0)
# Requirement already satisfied: pyclipper in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (1.3.0.post6)
# Requirement already satisfied: shapely in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (2.0.7)
# Requirement already satisfied: tqdm in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (4.67.1)
# Requirement already satisfied: validators in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras_ocr) (0.34.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from efficientnet==1.0.0->keras_ocr) (1.0.8)
# Requirement already satisfied: scikit-image in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from efficientnet==1.0.0->keras_ocr) (0.24.0)
# Requirement already satisfied: six in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (1.26.4)
# Requirement already satisfied: scipy in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (1.13.1)
# Requirement already satisfied: Pillow in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (11.1.0)
# Requirement already satisfied: matplotlib in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (3.9.4)
# Requirement already satisfied: opencv-python in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (4.11.0.86)
# Requirement already satisfied: imageio in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from imgaug->keras_ocr) (2.37.0)
# Requirement already satisfied: h5py in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (3.13.0)
# Requirement already satisfied: networkx>=2.8 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from matplotlib->imgaug->keras_ocr) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/beszabo/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug->keras_ocr) (3.21.0)

# %%
import math, keras_ocr,re, os
from groq import Groq
# Out:
# /Users/beszabo/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Function to get distances for detections
def get_distance(predictions):
    x0, y0 = 0, 0
    detections = []
    for group in predictions:
        top_left_x, top_left_y = group[1][0]
        bottom_right_x = group[1][1][0]
        bottom_right_y = group[1][3][1] # correct bottom-right coordinates
        center_x = (top_left_x + bottom_right_x) / 2
        center_y = (top_left_y + bottom_right_y) / 2
        distance_from_origin = math.dist([x0, y0], [center_x, center_y])
        distance_y = center_y - y0
        detections.append({
            "text": group[0],
            "center_x": center_x,
            "center_y": center_y,
            "distance_from_origin": distance_from_origin,
            "distance_y": distance_y,
        })
    return detections

# Function to distinguish rows
def distinguish_rows(lst, thresh=15):
    sublists = []
    for i in range(len(lst) - 1):
        if lst[i + 1]["distance_y"] - lst[i]["distance_y"] <= thresh:
            if lst[i] not in sublists:
                sublists.append(lst[i])
            sublists.append(lst[i + 1])
        else:
            yield sublists
            sublists = [lst[i + 1]]
    yield sublists
    
# Check for brand keywords
def contains_expression(word_list, expressions):
    result_list = []
    for key in expressions:
        key_lower = re.escape(key.lower())
        # Check if the key exists as a complete word
        if re.search(rf'\b{key_lower}\b', word_list):
            result_list.append(key)
        # Check if any of the associated values exist as complete words
        for value in expressions[key]:
            value_lower = re.escape(value.lower())
            if re.search(rf'\b{value_lower}\b', word_list):
                result_list.append(key)
    if(not result_list):
        return None
    return result_list

# %%
# Define the brands to be detected
def process_images_in_directory(directory, brands, brands_dict, api_key):
    for dirname, _, filenames in os.walk(directory):
        for filename in filenames:
            image_path = os.path.join(dirname, filename)

            # Initialize OCR pipeline
            pipeline = keras_ocr.pipeline.Pipeline()

            # Read image
            try:
                print(image_path)
                read_image = keras_ocr.tools.read(image_path)
                if read_image is None or read_image.size == 0:
                    raise ValueError("Image is empty or None")
            except Exception as e:
                print(f"Failed to read image: {image_path}. Error: {e}")
                continue

            # Recognize text in image
            prediction_groups = pipeline.recognize([read_image])

            # Process predictions
            predictions = get_distance(prediction_groups[0])

            # Order text detections
            predictions = distinguish_rows(predictions)
            if predictions is None:
                predictions = []

            predictions = list(filter(lambda x: x != [], predictions))
            ordered_preds = [each["text"] for row in predictions for each in sorted(row, key=lambda x: x["distance_from_origin"])]
            ordered_preds = " ".join(ordered_preds).lower()

            result_list = contains_expression(ordered_preds, brands)
            if result_list:
                for result in result_list:
                    # Prepare message for Groq API
                    if result in ["apple", "oracle", "amazon", "tesla", "oracle", "visa", "zara", "ge", "ford", "corona", "intel", "linkedin", "hp", "hermes"]:
                        system_message = f"you decide if the sentence is about {result} as a brand or the context says otherwise. Your answers can be: 'yes, no, cannot decide'"

                        # Proceed with the API call
                        client = Groq(api_key=api_key)
                        chat_completion = client.chat.completions.create(
                            messages=[
                                {"role": "system", "content": system_message},
                                {"role": "user", "content": ' '.join(ordered_preds)}
                            ],
                            model="llama3-70b-8192",
                        )

                        response_content = chat_completion.choices[0].message.content
                        if "yes" in response_content.lower():
                            if filename not in brands_dict[result]:
                                brands_dict[result].append(filename)
                    else:
                        if result is not None and filename not in brands_dict[result]:
                            brands_dict[result].append(filename)

    print(brands_dict)

# Example usage
process_images_in_directory('fake_deploy', brands, brands_dict, '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')
# Out:
# Looking for /Users/beszabo/.keras-ocr/craft_mlt_25k.h5
# Downloading /Users/beszabo/.keras-ocr/craft_mlt_25k.h5
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 767ms/step
# {'apple': [], 'microsoft': [], 'amazon': ['Amazon_image78_16_Amazon images.jpg', 'Amazon_image93_17_Amazon images.jpg', 'Image_23_Amazon images.jpg', 'Image_69_Amazon images.png', 'Amazon_image9_18_Amazon images.jpg', 'Image_42_Amazon images.png', 'Image_15_Amazon images.jpg', 'Image_2_Amazon images.jpg', 'Image_14_Amazon images.jpg', 'Image_56_Amazon images.jpg', 'Image_30_Amazon images.jpg', 'Image_66_Amazon images.jpg', 'Image_51_Amazon images.jpg', 'Image_8_Amazon images.jpg', 'Image_79_Amazon images.png', 'Image_9_Amazon images.jpeg'], 'google': [], 'samsung': [], 'toyota': [], 'mercedes-benz': [], 'coca-cola': [], 'nike': [], 'bmw': [], "mcdonald's": [], 'tesla': [], 'disney': [], 'louis vuitton': [], 'cisco': [], 'instagram': [], 'adobe': [], 'ibm': [], 'oracle': [], 'sap': [], 'facebook': [], 'chanel': [], 'hermes': [], 'intel': [], 'youtube': [], 'j.p. morgan': [], 'honda': [], 'american express': [], 'ikea': [], 'accenture': [], 'allianz': [], 'hyundai': [], 'ups': [], 'gucci': [], 'pepsi': [], 'sony': ['Ximages (6)_Amazon images.png'], 'visa': [], 'salesforce': [], 'netflix': [], 'paypal': [], 'mastercard': [], 'adidas': [], 'zara': [], 'axa': [], 'audi': [], 'airbnb': [], 'porsche': [], 'starbucks': [], 'ge': [], 'volkswagen': [], 'ford': [], 'nescafé': [], 'siemens': [], 'goldman sachs': [], 'pampers': [], 'h&m': [], 'l’oréal paris': [], 'citi': [], 'lego': [], 'red bull': [], 'budweiser': [], 'ebay': [], 'nissan': [], 'hp': [], 'hsbc': [], 'morgan stanley': [], 'nestle': [], 'philips': [], 'spotify': [], 'ferrari': [], 'nintendo': [], 'gillette': [], 'colgate': [], 'cartier': [], '3m': [], 'dior': [], 'santander': [], 'danone': [], "kellogg's": [], 'linkedin': [], 'corona': [], 'fedex': [], 'caterpillar': [], 'dhl': [], "jack daniel's": [], 'prada': [], 'xiaomi': [], 'kia': [], 'tiffany & co.': [], 'panasonic': [], 'hewlett packard enterprise': ['hp enterprise', 'hewlett packard'], 'huawei': [], 'hennessy': [], 'burberry': [], 'kfc': [], 'johnson & johnson': [], 'sephora': [], 'nespresso': [], 'heineken': [], 'canon': []}

# %%
non_empty_brands_dict = {key: value for key, value in brands_dict.items() if value}

print("Non-empty brands dictionary:")
for key, value in non_empty_brands_dict.items():
    print(f"{key}: {len(value)}")
# Out:
# Non-empty brands dictionary:
# amazon: 16
# sony: 1
# hewlett packard enterprise: 2

# %%
# Brands dictionary
brands = {
    "apple": ["iphone", "macbook", "ipad"],
    "microsoft": ["windows", "teams", "xbox"],
    "amazon": ["echo", "kindle", "amazon prime"],
    "google": ["gmail", "chrome"],
    "samsung": ["galaxy s"],
    "toyota": ["camry", "corolla"],
    "mercedes-benz": ["glc-class", "amg", "mercedes"],
    "coca-cola": ["be less white", "coke", "cocacola", "coca cola"],
    "nike": ["air max", "air jordan", "dri-fit", "just do it"],
    "bmw": ["Rolls-Royce", "x5", "m3"],
    "mcdonald's": ["big mac", "mcnuggets", "happy meal", "mcdonalds", "mcflurries"],
    "tesla": ["model s", "cyber truck", "model x"],
    "disney": ["mickey mouse", "encanto", "doorables"],
    "louis vuitton": ["speedy bag", "neverfull tote", "keepall bag"],
    "cisco": ["catalyst switches", "webex", "meraki"],
    "instagram": ["reels", "igtv"],
    "adobe": ["photoshop", "acrobat", "premiere pro"],
    "ibm": ["spss", "watson"],
    "oracle": ["java"],
    "sap": ["s/4hana", "successfactors", "ariba"],
    "facebook": ["messenger"],
    "chanel": ["no. 5", "boy bag", "classic flap"],
    "hermes": ["birkin"],
    "intel": ["core i7", "xeon", "pentium"],
    "youtube": [],
    "j.p. morgan": ["jp morgan"],
    "honda": ["civic", "cr-v"],
    "american express": ["platinum card", "amex"],
    "ikea": ["tempelhof", "poäng chair", "kallax"],
    "accenture": [],
    "allianz": [],
    "hyundai": ["elantra"],
    "ups": [],
    "gucci": ["gg marmont", "princetown loafers", "dionysus bag"],
    "pepsi": [],
    "sony": ["playstation", "bravia", "xperia"],
    "visa": [],
    "salesforce": [],
    "netflix": [],
    "paypal": ["zettle", "venmo", "braintree"],
    "mastercard": [],
    "adidas": ["ultraboost", "nmd", "superstar"],
    "zara": ["red temptation"],
    "axa": [],
    "audi": ["q5", "q7", "a8"],
    "airbnb": [],
    "porsche": ["taycan", "cayenne", "panamera"],
    "starbucks": ["frappuccino"],
    "ge": ["general electric"],
    "volkswagen": ["passat", "jetta", "tiguan"],
    "ford": ["mach e", "mach-e", "bronco", "f150"],
    "nescafé": ["dolce gusto"],
    "siemens": ["healthineers"],
    "goldman sachs": ["goldmansachs"],
    "pampers": ["swaddlers"],
    "h&m": ["conscious collection", "h and m", "hem"],
    "l’oréal paris": [
        "metal detox",
        "wonder water",
        "dream lengths",
        "loreal",
        "l'oreal",
    ],
    "citi": ["citigroup", "citibank"],
    "lego": ["piece 26047", "piece 32557", "piece 11031", "legos"],
    "red bull": [],
    "budweiser": ["bud light"],
    "ebay": [],
    "nissan": ["altima", "sentra", "pathfinder"],
    "hp": ["reverb g2", "envy 6055", "victus"],
    "hsbc": ["citizens bank", "zelle"],
    "morgan stanley": ["shareworks", "morganstanley"],
    "nestle": ["kitkat", "maggi", "toll house"],
    "philips": ["3200 lattego", "sonicare", "avent"],
    "spotify": [],
    "ferrari": ["488 gtb", "sf90", "daytona sp3", "purosangue"],
    "nintendo": ["switch lite", "switch oled", "switch games", "zelda", "mario"],
    "gillette": ["king c", "exfoliating razor"],
    "colgate": ["hum toothbrush", "optic white", "overnight pen"],
    "cartier": ["tank watch", "juste un clou", "tank must"],
    "3m": ["mmm"],
    "dior": ["sauvage", "dossier"],
    "santander": [],
    "danone": ["activia", "evian", "oikos", "danon"],
    "kellogg's": ["frosted flakes", "special k", "kelloggs","kellogg", "kellogs"],
    "linkedin": ["linked in"],
    "corona": [],
    "fedex": [],
    "caterpillar": ["cat 229d3", "cat 259d3", "cat engine"],
    "dhl": [],
    "jack daniel's": [
        "old no. 7",
        "jack honey",
        "tennessee honey",
        "jack daniels",
        "jack whiskey",
    ],
    "prada": ["paradoxe", "cleo bag", "cloudbust"],
    "xiaomi": ["mi 11", "redmi", "mi band"],
    "kia": ["sorento", "sportage", "telluride"],
    "tiffany & co.": ["tiffany co", "tiffany and co"],
    "panasonic": ["lumix", "toughbook", "s5 ii"],
    "hewlett packard enterprise": [
        "proliant",
        "nimble storage",
        "hewlett hackard",
        "hpe",
    ],
    "huawei": ["mate 60", "p30", "matebook"],
    "hennessy": ["pink whitney", "casamigos"],
    "burberry": ["goddess perfume", "her elixir", "her london dream"],
    "kfc": ["kentucky fried", "zinger", "kentucky chicken"],
    "johnson & johnson": ["jnj", "johnson johnson", "johnson and johnson", "johnson 8 johnson"],
    "sephora": [],
    "nespresso": ["vertuoline", "originalline", "vertuo"],
    "heineken": [],
    "canon": ["ts3322", "pixma", "ts3522"],
}

brands_dict = {
    "apple": [],
    "microsoft": [],
    "amazon": [],
    "google": [],
    "samsung": [],
    "toyota": [],
    "mercedes-benz": [],
    "coca-cola": [],
    "nike": [],
    "bmw": [],
    "mcdonald's": [],
    "tesla": [],
    "disney": [],
    "louis vuitton": [],
    "cisco": [],
    "instagram": [],
    "adobe": [],
    "ibm": [],
    "oracle": [],
    "sap": [],
    "facebook": [],
    "chanel": [],
    "hermes": [],
    "intel": [],
    "youtube": [],
    "j.p. morgan": [],
    "honda": [],
    "american express": [],
    "ikea": [],
    "accenture": [],
    "allianz": [],
    "hyundai": [],
    "ups": [],
    "gucci": [],
    "pepsi": [],
    "sony": [],
    "visa": [],
    "salesforce": [],
    "netflix": [],
    "paypal": [],
    "mastercard": [],
    "adidas": [],
    "zara": [],
    "axa": [],
    "audi": [],
    "airbnb": [],
    "porsche": [],
    "starbucks": [],
    "ge": [],
    "volkswagen": [],
    "ford": [],
    "nescafé": [],
    "siemens": [],
    "goldman sachs": [],
    "pampers": [],
    "h&m": [],
    "l’oréal paris": [],
    "citi": [],
    "lego": [],
    "red bull": [],
    "budweiser": [],
    "ebay": [],
    "nissan": [],
    "hp": [],
    "hsbc": [],
    "morgan stanley": [],
    "nestle": [],
    "philips": [],
    "spotify": [],
    "ferrari": [],
    "nintendo": [],
    "gillette": [],
    "colgate": [],
    "cartier": [],
    "3m": [],
    "dior": [],
    "santander": [],
    "danone": [],
    "kellogg's": [],
    "linkedin": [],
    "corona": [],
    "fedex": [],
    "caterpillar": [],
    "dhl": [],
    "jack daniel's": [],
    "prada": [],
    "xiaomi": [],
    "kia": [],
    "tiffany & co.": [],
    "panasonic": [],
    "hewlett packard enterprise": ["hp enterprise", "hewlett packard"],
    "huawei": [],
    "hennessy": [],
    "burberry": [],
    "kfc": [],
    "johnson & johnson": [],
    "sephora": [],
    "nespresso": [],
    "heineken": [],
    "canon": []
}
